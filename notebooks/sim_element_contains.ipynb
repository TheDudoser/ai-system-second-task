# %%
import json

from enum import Enum

class Mark(Enum):
    GREEN = 0
    ORANGE = 5
    RED = 10

# %%
class Interval:
    def __init__(self, left: float, right: float):
        if not isinstance(left, float) or not isinstance(right, float):
            raise TypeError("Левая и правая границы должны быть вещественными числами.")
        if left > right:
            raise ValueError("Левая граница должна быть меньше или равна правой границе.")
        self.left = float(left)
        self.right = float(right)

    # Проверка пересечения двух интервалов
    def intersects(self, other):
        return self.left <= other.right and other.left <= self.right

    # Проверка включения одного интервала в другой
    def contains_interval(self, other):
        return self.left <= other.left and self.right >= other.right

    # Проверка совпадения двух интервалов
    def __eq__(self, other):
        return self.left == other.left and self.right == other.right

    # Проверка принадлежности числа интервалу
    def contains_value(self, value):
        return self.left <= value <= self.right

    # Вычисление длины интервала
    def length(self):
        return self.right - self.left

    # Получение нижней границы интервала
    def get_left(self):
        return self.left

    # Получение верхней границы интервала
    def get_right(self):
        return self.right

# %%
with open("response.json", "r", encoding="utf-8") as file:
        json_file = json.loads(file.read())

# %%
def find_meta_value(data, meta):
  """
  Находит первый объект с заданным значением ключа "meta".

  Args:
    data: Данные в формате словаря или списка.
    meta: Искомое значение ключа "meta".

  Returns:
    Словарь с найденным объектом или None, если объект не найден.
  """
  if isinstance(data, dict):
    if 'meta' in data and data['meta'] == meta:
      return data
    for value in data.values():
      result = find_meta_value(value, meta)
      if result:
        return result
  elif isinstance(data, list):
    for item in data:
      result = find_meta_value(item, meta)
      if result:
        return result
  return None

# %%
def find_name_value(data, name):
    """
     Function to find an object with a given key "name" and its value.

     Args:
     data: Data in dictionary format.
     name: The searched value of the key "name".

     Returns:
     A dictionary with the found object or None if the object is not found.
    """

    if 'name' in data and data['name'] == name:
        return data

    for item in data.values():
        if isinstance(item, dict):
            result = find_name_value(item, name)
            if result:
                return result
        elif isinstance(item, list):
            for sub_item in item:
                result = find_name_value(sub_item, name)
                if result:
                    return result

    return None

# %%
def find_nested_element(data, key1, value1, key2, value2):
    def find_first_pair(data, key1, value1):
        if isinstance(data, dict):
            if key1 in data and data[key1] == value1:
                return data
            for key, value in data.items():
                if isinstance(value, dict):
                    result = find_first_pair(value, key1, value1)
                    if result is not None:
                        return result
                elif isinstance(value, list):
                    for item in value:
                        if isinstance(item, dict):
                            result = find_first_pair(item, key1, value1)
                            if result is not None:
                                return result
        elif isinstance(data, list):
            for item in data:
                result = find_first_pair(item, key1, value1)
                if result is not None:
                    return result
        return None

    first_pair_dict = find_first_pair(data, key1, value1)

    if first_pair_dict:
        return find_first_pair(first_pair_dict, key2, value2)

    return None

# %%
result_1 = find_name_value(json_file,"12Х18Н10Т") 
print(result_1)
#12Х18Н10Т
# Out:
# {'id': 381405980786784, 'name': '12Х18Н10Т', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Материал', 'successors': [{'id': 381405980786788, 'name': 'Элементный состав', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Элементный состав', 'successors': [{'id': 381405980798316, 'name': 1, 'type': 'НЕТЕРМИНАЛ', 'meta': 'Компонент', 'successors': [{'id': 381405980798320, 'name': 'Fe', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Железо/Fe;', 'successors': [{'id': 381405980798326, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980798328, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980798332, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980798342, 'value': 66.7, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980798336, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980798346, 'value': 70.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}]}, {'id': 381405980798360, 'name': 2, 'type': 'НЕТЕРМИНАЛ', 'meta': 'Компонент', 'successors': [{'id': 381405980793168, 'name': 'Cr', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Хром/Cr;', 'successors': [{'id': 381405980793354, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793332, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980793336, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795946, 'value': 17.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980793340, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795950, 'value': 19.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}]}, {'id': 381405980798364, 'name': 3, 'type': 'НЕТЕРМИНАЛ', 'meta': 'Компонент', 'successors': [{'id': 381405980793192, 'name': 'Ni', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Никель/Ni;', 'successors': [{'id': 381405980793358, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793360, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980793364, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795954, 'value': 9.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980793368, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795958, 'value': 11.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}]}, {'id': 381405980798368, 'name': 4, 'type': 'НЕТЕРМИНАЛ', 'meta': 'Компонент', 'successors': [{'id': 381405980793216, 'name': 'Mn', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Марганец/Mn;', 'successors': [{'id': 381405980793382, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793384, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980793390, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795962, 'value': 2.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}, {'id': 381405980798372, 'n ...

# %%
result_1 = find_name_value(result_1,"Элементный состав")

# %%
find_name_value(json_file,"Ст3сп")
# Out:
# {'id': 381405980799364,
#  'name': 'Ст3сп',
#  'type': 'НЕТЕРМИНАЛ',
#  'meta': 'Материал',
#  'successors': [{'id': 381405980799368,
#    'name': 'Элементный состав',
#    'type': 'НЕТЕРМИНАЛ',
#    'meta': 'Элементный состав',
#    'successors': [{'id': 381405980799372,
#      'name': 1,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799376,
#        'name': 'Fe',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Железо/Fe;',
#        'successors': [{'id': 381405980799382,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799386,
#          'value': 97.0,
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'REAL',
#          'meta': 'Числовое значение'}]}]},
#     {'id': 381405980799396,
#      'name': 2,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799400,
#        'name': 'Mn',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Марганец/Mn;',
#        'successors': [{'id': 381405980799406,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799408,
#          'name': 'Числовой интервал',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Числовой интервал',
#          'successors': [{'id': 381405980799412,
#            'name': 'Нижняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Нижняя граница',
#            'successors': [{'id': 381405980799422,
#              'value': 0.4,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]},
#           {'id': 381405980799416,
#            'name': 'Верхняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Верхняя граница',
#            'successors': [{'id': 381405980799426,
#              'value': 0.65,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]}]}]}]},
#     {'id': 381405980799428,
#      'name': 3,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799432,
#        'name': 'Si',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Кремний/Si;',
#        'successors': [{'id': 381405980799438,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799440,
#          'name': 'Числовой интервал',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Числовой интервал',
#          'successors': [{'id': 381405980799444,
#            'name': 'Нижняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Нижняя граница',
#            'successors': [{'id': 381405980799454,
#              'value': 0.15,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]},
#           {'id': 381405980799448,
#            'name': 'Верхняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Верхняя граница',
#            'successors': [{'id': 381405980799458,
#              'value': 0.3,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]}]}]}]},
#     {'id': 381405980799460,
#      'name': 4,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799464,
#        'name': 'C',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Углерод/C;',
#        'successors': [{'id': 381405980799470,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799472,
#          'name': 'Числовой интервал',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Числовой интервал',
#          'successors': [{'id': 381405980799476,
#            'name': 'Нижняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Нижняя граница',
#            'successors': [{'id': 381405980799486,
#              'value': 0.14,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]},
#           {'id': 381405980799480,
#            'name': 'Верхняя граница',
#            'type': 'НЕТЕРМИНАЛ',
#            'meta': 'Верхняя граница',
#            'successors': [{'id': 381405980799490,
#              'value': 0.22,
#              'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#              'valtype': 'REAL',
#              'meta': 'Числовое значение'}]}]}]}]},
#     {'id': 381405980799492,
#      'name': 5,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799496,
#        'name': 'Ni',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Никель/Ni;',
#        'successors': [{'id': 381405980799502,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799504,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799510,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799514,
#            'value': 0.3,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799516,
#      'name': 6,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799520,
#        'name': 'Cr',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Хром/Cr;',
#        'successors': [{'id': 381405980799526,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799528,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799534,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799538,
#            'value': 0.3,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799540,
#      'name': 7,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799544,
#        'name': 'Медь',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Медь;',
#        'successors': [{'id': 381405980799550,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799552,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799558,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799562,
#            'value': 0.3,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799564,
#      'name': 8,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799568,
#        'name': 'As',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Мышьяк/As;',
#        'successors': [{'id': 381405980799574,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799576,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799582,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799586,
#            'value': 0.08,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799588,
#      'name': 9,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799592,
#        'name': 'S',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Сера/S;',
#        'successors': [{'id': 381405980799598,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799600,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799606,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799610,
#            'value': 0.05,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799612,
#      'name': 10,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799616,
#        'name': 'P',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Фосфор/P;',
#        'successors': [{'id': 381405980799622,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799624,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799630,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799634,
#            'value': 0.04,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799636,
#      'name': 11,
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Компонент',
#      'successors': [{'id': 381405980799640,
#        'name': 'N',
#        'type': 'НЕТЕРМИНАЛ',
#        'meta': 'Химический элемент',
#        'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Азот/N;',
#        'successors': [{'id': 381405980799646,
#          'value': '%',
#          'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#          'valtype': 'STRING',
#          'meta': '%'},
#         {'id': 381405980799648,
#          'name': 'Не более',
#          'type': 'НЕТЕРМИНАЛ',
#          'meta': 'Не более',
#          'successors': [{'id': 381405980799654,
#            'value': '≤',
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'STRING',
#            'meta': '≤'},
#           {'id': 381405980799658,
#            'value': 0.008,
#            'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#            'valtype': 'REAL',
#            'meta': 'Числовое значение'}]}]}]},
#     {'id': 381405980799388,
#      'name': 'Основа',
#      'type': 'НЕТЕРМИНАЛ',
#      'meta': 'Основа',
#      'successors': [{'id': 381405980799394,
#        'value': 'Fe',
#        'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ',
#        'valtype': 'STRING',
#        'meta': 'Химический элемент',
#        'original': 'Справочник по материалам$/Сплавы на основе железа/Ст3сп/Элементный состав/1/Fe;'}]}]}]}

# %%
def osnov_compare(json1,json2):
    osnov_1 = find_meta_value(json1,"Основа")
    osnov_2 = find_meta_value(json2,"Основа")
   
    values_1 = [item['value'] for item in osnov_1['successors']]
    values_2 = [item['value'] for item in osnov_2['successors']]

    if values_1 == values_2 :


        if json1 is None and  json2 is not None:
            return Mark.RED 

        elif json1 is None and  json2 is  None:
            return Mark.GREEN

        else:
            pair_counter = 0 #счетчик пар
            green_counter = 0

            for component in json1["successors"]:
                
                chim_element_1 = find_meta_value(component,"Химический элемент")

                if chim_element_1 is None or chim_element_1.get("name",None) is None:
                    continue
                
                
                print("chim_element_1",chim_element_1)

                
                for component_2 in json2["successors"]:
                
                    
                    chim_element_2 = find_name_value(component_2,chim_element_1["name"])
                    

                    if chim_element_2 is not None:

                        pair_counter+=1
                        
                        number_interval_1 = find_meta_value(chim_element_1,'Числовой интервал')
                        number_interval_2 = find_meta_value(chim_element_2,'Числовой интервал')
                        
                        not_bigger_1 = find_meta_value(chim_element_1,"Не более")
                        not_bigger_2 = find_meta_value(chim_element_2,"Не более")

                        
                        
                        if  number_interval_1 is not None and number_interval_2 is not None: #3.1 
                            

                            low_border_1 = find_meta_value(number_interval_1,'Нижняя граница')
                            top_border_1 = find_meta_value(number_interval_1,'Верхняя граница')
                            
                            print("low_border_1",low_border_1)
                            print("top_border_1",top_border_1)

                            interval_1 = Interval(float(low_border_1["successors"][0]["value"]),float(top_border_1["successors"][0]["value"]))

                            low_border_2 = find_meta_value(number_interval_2,'Нижняя граница')
                            top_border_2 = find_meta_value(number_interval_2,'Верхняя граница')

                            interval_2 = Interval(float(low_border_2["successors"][0]["value"]),float(top_border_2["successors"][0]["value"]))

                            if interval_1.contains_interval(interval_2):
                                green_counter+=1

                        elif (not_bigger_1 is not None and number_interval_2 is not None) or (not_bigger_2 is not None and number_interval_1 is not None): #3.2
                            
                            if not_bigger_1 is not None:
                                
                                interval_value_1 = find_meta_value(not_bigger_1["successors"],'Числовое значение')
                                
                                interval_1 = Interval(0.0 , float(interval_value_1["value"]))

                                low_border_2 = find_meta_value(number_interval_2,'Нижняя граница')
                                top_border_2 = find_meta_value(number_interval_2,'Верхняя граница')
                                
                                interval_2 = Interval(float(low_border_2["successors"][0]["value"]),float(top_border_2["successors"][0]["value"]))
                            
                                if interval_1.contains_interval(interval_2):
                                    green_counter+=1

                                
                        
                        elif not_bigger_1 is not None and not_bigger_2 is not None : #3.3
                       

                            interval_value_2 = find_meta_value(chim_element_2["successors"],'Числовое значение')
                          
                            #interval_2 = Interval(0.0 , float(interval_value_2["value"]))

                           
                            
                            not_bigger_1 = find_meta_value(chim_element_1,"Не более")

                            interval_value_1 = find_meta_value(chim_element_1["successors"],'Числовое значение')
                          
                           # interval_1 = Interval(0.0 , float(interval_value_1["value"]))


                            if interval_value_1 == interval_value_2:
                                green_counter+=1
       
        if green_counter/pair_counter  >= 0.9:
            return Mark.GREEN
        elif green_counter/pair_counter >= 0.7:
            return Mark.ORANGE
        else:
            return Mark.RED 
           
    else: 
        return Mark.RED

# %%
osnov_compare(result_1,result_1)
# Out:
# chim_element_1 {'id': 381405980798320, 'name': 'Fe', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Железо/Fe;', 'successors': [{'id': 381405980798326, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980798328, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980798332, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980798342, 'value': 66.7, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980798336, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980798346, 'value': 70.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}
# low_border_1 {'id': 381405980798332, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980798342, 'value': 66.7, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# top_border_1 {'id': 381405980798336, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980798346, 'value': 70.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# chim_element_1 {'id': 381405980793168, 'name': 'Cr', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Хром/Cr;', 'successors': [{'id': 381405980793354, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793332, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980793336, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795946, 'value': 17.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980793340, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795950, 'value': 19.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}
# low_border_1 {'id': 381405980793336, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795946, 'value': 17.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# top_border_1 {'id': 381405980793340, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795950, 'value': 19.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# chim_element_1 {'id': 381405980793192, 'name': 'Ni', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Никель/Ni;', 'successors': [{'id': 381405980793358, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793360, 'name': 'Числовой интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Числовой интервал', 'successors': [{'id': 381405980793364, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795954, 'value': 9.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}, {'id': 381405980793368, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795958, 'value': 11.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}
# low_border_1 {'id': 381405980793364, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980795954, 'value': 9.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# top_border_1 {'id': 381405980793368, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980795958, 'value': 11.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}
# chim_element_1 {'id': 381405980793216, 'name': 'Mn', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Марганец/Mn;', 'successors': [{'id': 381405980793382, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980793384, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980793390, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795962, 'value': 2.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# chim_element_1 {'id': 381405980795740, 'name': 'Ti', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Титан/Ti;', 'successors': [{'id': 381405980795746, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980798376, 'name': 'Расчетное', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Расчетное', 'successors': [{'id': 381405980798380, 'name': 'Интервал', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Интервал', 'successors': [{'id': 381405980798384, 'name': 'Нижняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Нижняя граница', 'successors': [{'id': 381405980798410, 'value': 5.0, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'коэффициент'}, {'id': 381405980798414, 'value': 'C', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': 'Химический элемент', 'original': 'Справочник по материалам$/Сплавы на основе железа/12Х18Н10Т/Элементный состав/8/C;'}]}, {'id': 381405980798388, 'name': 'Верхняя граница', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Верхняя граница', 'successors': [{'id': 381405980798406, 'value': 0.8, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}]}]}
# chim_element_1 {'id': 381405980795720, 'name': 'Si', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Кремний/Si;', 'successors': [{'id': 381405980795726, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980795728, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980795734, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795966, 'value': 0.8, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# chim_element_1 {'id': 381405980795748, 'name': 'Cu', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Медь/Cu;', 'successors': [{'id': 381405980795754, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980795756, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980795762, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795970, 'value': 0.3, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# chim_element_1 {'id': 381405980795772, 'name': 'C', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Углерод/C;', 'successors': [{'id': 381405980795778, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980795780, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980795786, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795974, 'value': 0.12, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# chim_element_1 {'id': 381405980795796, 'name': 'P', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Фосфор/P;', 'successors': [{'id': 381405980795802, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980795804, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980795810, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795978, 'value': 0.035, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# chim_element_1 {'id': 381405980795820, 'name': 'S', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Химический элемент', 'original': 'vadim@dvo.ru / Мой Фонд / Лазерное аддитивное производство / База химических элементов$/Сера/S;', 'successors': [{'id': 381405980795826, 'value': '%', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '%'}, {'id': 381405980795828, 'name': 'Не более', 'type': 'НЕТЕРМИНАЛ', 'meta': 'Не более', 'successors': [{'id': 381405980795834, 'value': '≤', 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'STRING', 'meta': '≤'}, {'id': 381405980795982, 'value': 0.02, 'type': 'ТЕРМИНАЛ-ЗНАЧЕНИЕ', 'valtype': 'REAL', 'meta': 'Числовое значение'}]}]}
# <Mark.GREEN: 0>
